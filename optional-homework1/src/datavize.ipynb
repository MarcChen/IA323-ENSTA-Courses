# %%
from torchvision import datasets
import os
import matplotlib.pyplot as plt

# %%
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
path = os.path.join(project_root, 'data')
# Check if the dataset is already downloaded
if os.path.exists(os.path.join(path, 'FashionMNIST', 'raw')):
    print("Dataset already downloaded in data folder !")
    train_dataset = datasets.FashionMNIST(root=path, train=True, download=False)
else :
    # Download the dataset and store it in the path
    datasets.FashionMNIST(root=path, train=True, download=True)
    datasets.FashionMNIST(root=path, train=False, download=True)
# Out:
# Dataset already downloaded in data folder !

# %%
img, label = train_dataset[35]
img, label
f=plt.figure(figsize=(16,16))
set={-1}
i=0
for x in range(0,25):
    
    img, label=train_dataset[x+1]
    if label not in set:
        f.add_subplot(1, 10, i+ 1)
        i+=1
        plt.imshow(img, cmap='gray')
        plt.title(f"{class_names[label]}")
        set.add(label)
plt.show()

# %%
class_names = train_dataset.classes
print(f"Classes label {class_names}")
print(f"Number of classes {len(class_names)}")
print(f"Number of training examples {len(train_dataset)}")
# Out:
# Classes label ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
# Number of classes 10
# Number of training examples 60000
